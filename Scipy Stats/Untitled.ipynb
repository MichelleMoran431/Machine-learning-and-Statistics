# %%
# Data frames.
import pandas as pd

# Plotting.
import seaborn as sns

# Stats.
import scipy.stats as ss

# Numerical arrays.
import numpy as np

# Collections.
import collections as co

# Specials.
import scipy.special as spec


# For plotting 
import plotly as py
import plotly.graph_objects as go
from plotly.offline import iplot
import plotly.express as px

# %%
Diet = pd.read_csv(r'C:\Users\User\Desktop\repo\Machine-learning-and-Statistics\Scipy Stats\Diet_R.csv')
Diet
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  Weight loss
# 0       25          41     171          60     2          60.0          0.0
# 1       26          32     174         103     2         103.0          0.0
# 2        1      0   22     159          58     1          54.2          3.8
# 3        2      0   46     192          60     1          54.0          6.0
# 4        3      0   55     170          64     1          63.3          0.7
# ..     ...    ...  ...     ...         ...   ...           ...          ...
# 73      74      1   35     183          83     3          80.2          2.8
# 74      75      1   49     177          84     3          79.9          4.1
# 75      76      1   28     164          85     3          79.7          5.3
# 76      77      1   40     167          87     3          77.8          9.2
# 77      78      1   51     175          88     3          81.9          6.1
#
# [78 rows x 8 columns]

# %%
Diet.dtypes
# Out:
# Person            int64
# gender           object
# Age               int64
# Height            int64
# pre.weight        int64
# Diet              int64
# weight6weeks    float64
# Weight loss       int32
# dtype: object

# %%
Diet.dtypes
# Out:
# Person            int64
# gender           object
# Age               int64
# Height            int64
# pre.weight        int64
# Diet              int64
# weight6weeks    float64
# Weight loss       int32
# dtype: object

# %%
df.
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Length: 78, dtype: bool

# %% [markdown]
# ## Pivoting the dataframe
# To facilitate the calculation for ANOVA, we need to pivot the dataframe:

# %%
Diet1= Diet[Diet["Diet"]==1] #extracting Diet group 1

# %%
Diet1
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  Weight loss
# 2        1      0   22     159          58     1          54.2            3
# 3        2      0   46     192          60     1          54.0            6
# 4        3      0   55     170          64     1          63.3            0
# 5        4      0   33     171          64     1          61.1            2
# 6        5      0   50     170          65     1          62.2            2
# 7        6      0   50     201          66     1          64.0            2
# 8        7      0   37     174          67     1          65.0            2
# 9        8      0   28     176          69     1          60.5            8
# 10       9      0   28     165          70     1          68.1            1
# 11      10      0   45     165          70     1          66.9            3
# 12      11      0   60     173          72     1          70.5            1
# ...

# %%
Diet1
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  Weight loss
# 2        1      0   22     159          58     1          54.2            3
# 3        2      0   46     192          60     1          54.0            6
# 4        3      0   55     170          64     1          63.3            0
# 5        4      0   33     171          64     1          61.1            2
# 6        5      0   50     170          65     1          62.2            2
# 7        6      0   50     201          66     1          64.0            2
# 8        7      0   37     174          67     1          65.0            2
# 9        8      0   28     176          69     1          60.5            8
# 10       9      0   28     165          70     1          68.1            1
# 11      10      0   45     165          70     1          66.9            3
# 12      11      0   60     173          72     1          70.5            1
# ...

# %%
print("\n".join(Diet1.sort_values.__doc__.split("\n")[1:2]))
# Out:
# Sort by the values along either axis.

# %%
Diet1=Diet1.sort_values(by="gender")

# %%
print("\n".join(Diet1.to_numpy.__doc__.split("\n")[1:2]))
# Out:
#         Convert the DataFrame to a NumPy array.

# %%
Diet1=Diet1["Weight loss"].to_numpy()

# %%
Diet1.shape
# Out:
# (24,)

# %% [markdown]
# Diet 2 is a second measure after some intervention on the same person via ID [6]

# %%
Diet2= Diet[Diet["Diet"]==2] #extracting Diet group 2

# %%
Diet2=Diet2.sort_values(by="gender") # sort by ID

# %%
Diet2 = Diet2["Weight loss"].to_numpy() # to numpy array

# %%
Diet2.shape
# Out:
# (27,)

# %% [markdown]
# testing if there is a difference between drugA and drugB [6]

# %%
print("\n".join(ss.ttest_rel.__doc__.split("\n")[1:5]))
# Out:
#     Calculate the t-test on TWO RELATED samples of scores, a and b.
#
#     This is a two-sided test for the null hypothesis that 2 related or
#     repeated samples have identical average (expected) values.

# %%
def welch_ttest(x, y): 
    ## Welch-Satterthwaite Degrees of Freedom ##
    dof = (x.var()/x.size + y.var()/y.size)**2 / ((x.var()/x.size)**2 / (x.size-1) + (y.var()/y.size)**2 / (y.size-1))
   
    t, p = ss.ttest_ind(x,y,equal_var = False)

    print("\n"
          f"Welch's t-test= {t:.4f}"
          f"p-value = {p:.4f}"
          f"Welch-Satterthwaite Degrees of Freedom= {dof:.4f}")

welch_ttest(Diet1['Weight loss'], Diet2['Weight loss'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-b01a640b4536> in <module>
#      10           f"Welch-Satterthwaite Degrees of Freedom= {dof:.4f}")
#      11
# ---> 12 welch_ttest(Diet1['Weight loss'], Diet2['Weight loss'])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
Diet.groupby("Diet")['Weight loss'].describe()
# Out:
#       count      mean       std  min   25%  50%   75%  max
# Diet
# 1      24.0  2.916667  2.282574  0.0  1.75  3.0  3.25  9.0
# 2      27.0  2.740741  2.363059 -2.0  1.00  3.0  4.00  7.0
# 3      27.0  4.703704  2.508674  0.0  3.00  5.0  7.00  9.0

# %%
Diet1 = Diet[(Diet['Diet'] == '1')]
Diet2 = Diet[(Diet['Diet'] == '2')]

# %%
from scipy import stats

stats.shapiro(Diet1['Weight loss'])
stats.shapiro(Diet2['Weight loss'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-9a6d1da5a65e> in <module>
#       1 from scipy import stats
#       2
# ----> 3 stats.shapiro(Diet1['Weight loss'])
#       4 stats.shapiro(Diet2['Weight loss'])
#
# ~\anaconda3\lib\site-packages\scipy\stats\morestats.py in shapiro(x)
#    1668     N = len(x)
#    1669     if N < 3:
# -> 1670         raise ValueError("Data must be at least length 3.")
#    1671
#    1672     a = zeros(N, 'f')
#
# ValueError: Data must be at least length 3.

# %%
stats.ttest_ind(Diet1['Weight loss'], Diet2['Weight loss'], equal_var = False)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %% [markdown]
# ## Step 1 — Calculating the means for all groups

# %%
df.loc['Group Means'] = df.mean()
df

# %%
overall_mean = df.iloc[-1].mean()
overall_mean

# %% [markdown]
# ## Step 2 — Calculate the Sum of Squares

# %% [markdown]
# Sum of squares of all observation — SS_total
# Sum of squares within — SS_within
# Sum of squares between — SS_between
# Sum of squares of all observation — SS_total
# The sum of squares of all observation is calculated by deducting each observation from the overall mean, and then summing all the squares of the differences:
#
# Image by author

# %%
SS_total = (((df.iloc[:-1] - overall_mean)**2).sum()).sum()
SS_total   # 1002.6666666666667
